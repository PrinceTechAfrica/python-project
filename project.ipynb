# %%
# Create class Student
class Student:

    def __init__(self, name,level,matricNo, roll, s1, s2):
        self.name = name
        self.roll = roll
        self.s1 = s1
        self.s2 = s2
        self.level=level
        self.matricNo=matricNo

    # Function to create and append students
    def accept(self, Name,level,matricNo, Roll, score1, score2):
        obj = Student(Name, level,matricNo,Roll, score1, score2)
        ls.append(obj)

    # Display student details
    def display(self, obj):
        print("Name : ", obj.name)
        print("Level : ", obj.level)
        print("MatricNumber : ", obj.matricNo)
        print("RollNo : ", obj.roll)
        print("Score1 : ", obj.s1)
        print("Score2 : ", obj.s2)
        print("\n")

    # Search Function
    def search(self, rn):
        for i in range(ls.__len__()):
            if (ls[i].roll == rn):
                return i

            # Deletion

    def delete(self, rn):
        i = obj1.search(rn)
        del ls[i]

    # Update Function
    def update(self, rn, No):
        i = obj1.search(rn)
        rolln = No
        ls[i].roll = rolln;


ls = []
# Object of class
obj1 = Student('','',0, 0, 0, 0)

print("\nOperations used, ")
print("\n1.Accept Student details\n"
      "2.Display Student Details\n" 
       "3.Search Details of a Student\n"
        "4.Delete Details of Student" 
      "\n5.Update Student Details\n6.Exit")


obj1.accept("Emeka",100,'EBSU/2015', 1, 80, 70)
obj1.accept("Adobi",100,'EBSU/2015', 2, 90, 90)
obj1.accept("Jerome",100,'EBSU/2015', 3, 80, 80)
obj1.accept("Chinaza",100,'EBSU/2015', 3, 80, 80)

print("\n")
print("\nList of Students\n")
for i in range(ls.__len__()):
    obj1.display(ls[i])

print("\n Student Found, ")
s = obj1.search(1)
obj1.display(ls[s])

obj1.delete(2)
print(ls.__len__())
print("List after deletion")
for i in range(ls.__len__()):
    obj1.display(ls[i])

obj1.update(3, 2)
print(ls.__len__())
print("List after updating")
for i in range(ls.__len__()):
    obj1.display(ls[i])


print("Thank You !")
# Out:
# Operations used,
#
# 1.Accept Student details
# 2.Display Student Details
# 3.Search Details of a Student
# 4.Delete Details of Student
# 5.Update Student Details
# 6.Exit
#
#
#
# List of Students
#
# Name :  Emeka
# Level :  100
# MatricNumber :  EBSU/2015
# RollNo :  1
# Score1 :  80
# Score2 :  70
#
#
# Name :  Adobi
# Level :  100
# MatricNumber :  EBSU/2015
# RollNo :  2
# Score1 :  90
# Score2 :  90
#
#
# Name :  Jerome
# Level :  100
# MatricNumber :  EBSU/2015
# RollNo :  3
# Score1 :  80
# Score2 :  80
#
#
# Name :  Chinaza
# Level :  100
# MatricNumber :  EBSU/2015
# RollNo :  3
# Score1 :  80
# Score2 :  80
#
#
#
#  Student Found,
# Name :  Emeka
# Level :  100
# MatricNumber :  EBSU/2015
# RollNo :  1
# Score1 :  80
# Score2 :  70
#
#
# 3
# List after deletion
# Name :  Emeka
# Level :  100
# MatricNumber :  EBSU/2015
# RollNo :  1
# Score1 :  80
# Score2 :  70
#
#
# Name :  Jerome
# Level :  100
# MatricNumber :  EBSU/2015
# RollNo :  3
# Score1 :  80
# Score2 :  80
#
#
# ...
